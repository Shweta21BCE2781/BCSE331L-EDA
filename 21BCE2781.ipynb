# %% [markdown]
# <a href="https://colab.research.google.com/github/Shweta21BCE2781/BCSE331L-EDA/blob/main/21BCE2781.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SHWETA SUKHTANKAR**
# # **21BCE2781**

# %% [markdown]
# # Module 2

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/salemprakash/EDA/main/Data/Employee%20Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
# Dataset dimensions
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# From the shape of the dataset we know that there are 1470 rows and 35 columns(attributes) in the table

# %%
df.describe()
# Will give the statistical summary of numeric columns in the dataset
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.info() # Will show information about the data types of all the 35 attributes
# We can also see if any might have any missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# Since each of the columns has 1470 non null count we can conclude that the dataset does not have any missing values

# %% [markdown]
# Getting an understanding of categorical varaiables in the dataset.
# We will see the count of each unique value for each categorical variable

# %%
df['BusinessTravel'].value_counts()
# Out:
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
df['EducationField'].value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
df['JobRole'].value_counts()
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64

# %%
df['Over18'].value_counts()
# Out:
# Over18
# Y    1470
# Name: count, dtype: int64

# %%
df['OverTime'].value_counts()
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %% [markdown]
# # Data Handling
#
# Search for missing values - we already saw that we dont have any missing values in the dataset but just to confirm

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# We have confirmed that there are no missing values
#
# Now we should check for duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No duplicate values either

# %% [markdown]
# # Outlier detection and filtering
#
# We can check for outliers using boxplots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure()
sns.boxplot(data=df[['Age', 'DailyRate','DistanceFromHome']])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df[['Education','EmployeeCount','EmployeeNumber', 'MonthlyIncome', 'YearsAtCompany']])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df[['EnvironmentSatisfaction','HourlyRate','JobInvolvement', 'JobLevel', 'JobSatisfaction']])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df[['MonthlyIncome','MonthlyRate','NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating']])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df[['RelationshipSatisfaction','StandardHours','StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear']])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df[['WorkLifeBalance','YearsAtCompany','YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']])
plt.show()

# %% [markdown]
# There are outliers in 'YearsAtCompany','YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager','StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear','MonthlyIncome','NumCompaniesWorked', 'PerformanceRating','MonthlyIncome'
#
#
# The outliers are outside the range of:
# ( Q1-1.5IQR , Q3+1.5IQR )
#
# So we can remove them using this formula

# %%
columns = ['YearsAtCompany','YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager','StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear','MonthlyIncome','NumCompaniesWorked', 'PerformanceRating','MonthlyIncome']
for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1  # Interquartile range

        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR

        df = df[(df[col] >= lower) & (df[col] <= upper)]

# %% [markdown]
# # Module 3

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

# Select only numerical columns
numerical_df = df.select_dtypes(include=['number'])

# %% [markdown]
# # Central Tendency Measures
# ###  Univariate Analysis

# %%
central_tendency = numerical_df.agg(['mean', 'median'])
display(central_tendency)
# Out:
#               Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# mean    34.478916  807.51506          9.286145   2.843373            1.0
# median  34.000000  807.00000          7.000000   3.000000            1.0
#
#         EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# mean       1043.436747                 2.722892   65.814759        2.736446
# median     1034.500000                 3.000000   66.000000        3.000000
#
#         JobLevel  ...  RelationshipSatisfaction  StandardHours  \
# mean    1.612952  ...                  2.724398           80.0
# median  2.000000  ...                  3.000000           80.0
#
#         StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# mean            0.641566           7.933735               2.525602
# median          1.000000           8.000000               2.000000
#
#         WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# ...

# %% [markdown]
# ### Dispersion Measures

# %%
dispersion = numerical_df.agg(['min', 'max', 'var', 'std'])
display(dispersion)
# Out:
#            Age      DailyRate  DistanceFromHome  Education  EmployeeCount  \
# min  18.000000     103.000000          1.000000   1.000000            1.0
# max  60.000000    1498.000000         29.000000   5.000000            1.0
# var  67.788393  160347.719230         65.453443   1.067437            0.0
# std   8.233371     400.434413          8.090330   1.033169            0.0
#
#      EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# min        4.000000                 1.000000   30.000000        1.000000
# max     2068.000000                 4.000000  100.000000        4.000000
# var   367154.575179                 1.174980  419.206961        0.508112
# std      605.932814                 1.083965   20.474544        0.712819
#
#      JobLevel  ...  RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# min  1.000000  ...                  1.000000           80.0          0.000000
# ...

# %% [markdown]
# ### Interquartile Range (IQR)

# %%
iqr = numerical_df.quantile([0.25, 0.75])
iqr.loc['IQR'] = iqr.loc[0.75] - iqr.loc[0.25]
display(iqr)
# Out:
#        Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0.25  29.0      471.0               2.0        2.0            1.0
# 0.75  39.0     1167.5              14.0        4.0            1.0
# IQR   10.0      696.5              12.0        2.0            0.0
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0.25          501.75                      2.0        48.0             2.0
# 0.75         1574.75                      4.0        84.0             3.0
# IQR          1073.00                      2.0        36.0             1.0
#
#       JobLevel  ...  RelationshipSatisfaction  StandardHours  \
# 0.25       1.0  ...                       2.0           80.0
# 0.75       2.0  ...                       4.0           80.0
# IQR        1.0  ...                       2.0            0.0
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0.25               0.0                5.0                    2.0
# ...

# %% [markdown]
# ### Histograms of Numerical Variables

# %%
num_cols = len(numerical_df.columns)
num_rows = (num_cols + 3) // 4

# subplots
fig, axes = plt.subplots(nrows=num_rows, ncols=4, figsize=(16, 4 * num_rows))
axes = axes.flatten()

for i, col in enumerate(numerical_df.columns):
    sns.histplot(numerical_df[col], bins=30, kde=True, ax=axes[i])
    axes[i].set_title(f"Histogram of {col}")
    axes[i].set_xlabel("")
    axes[i].set_ylabel("Frequency")

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Boxplots of Numerical Variables

# %%
# Boxplots
plt.figure(figsize=(12, 6))
sns.boxplot(data=numerical_df)
plt.xticks(rotation=45)
plt.title("21BCE2781 - Boxplots of Numerical Variables")
plt.show()

# %% [markdown]
# # Bivariate Analysis
# ### Correlation Matrix

# %%
correlation_matrix = numerical_df.corr()
display(correlation_matrix)
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.034869          0.034667   0.261146
# DailyRate                 0.034869   1.000000         -0.017861  -0.034392
# DistanceFromHome          0.034667  -0.017861          1.000000  -0.030178
# Education                 0.261146  -0.034392         -0.030178   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber            0.017726  -0.053393          0.028440   0.104577
# EnvironmentSatisfaction   0.006780   0.099589         -0.040134  -0.014571
# HourlyRate                0.025052   0.008761         -0.004451  -0.023121
# JobInvolvement            0.059061   0.051754          0.000543   0.060602
# JobLevel                  0.284088   0.052817          0.103466   0.132714
# JobSatisfaction           0.028035   0.057832          0.058312  -0.014963
# ...

# %% [markdown]
# **Correlation Levels :**
#
#
# 1. No Correlation: Variables that have a
# correlation close to zero.
#
# 2. Weak Correlation: Variables with a correlation between 0.1 and 0.3.
#
# 3. Strong Correlation: Variables with a correlation above 0.7 (or below -0.7).

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("21BCE2781 - Correlation Heatmap")
plt.show()

# %% [markdown]
# **Summary of Correlation Findings**
#
#
# **Strongly Correlated Variables :**
#
# 1. Job Level and Monthly Income (r = 0.84)
# 2. Total Working Years and Years at Company (r = 0.49)
# 3. Years at Company and Years in Current Role (r = 0.85)
# 4. Years at Company and Years with Current Manager (r = 0.83)
#
# **Moderately Correlated Variables :**
# 1. Age and Total Working Years (r = 0.52)
# 2. Job Level and Total Working Years (r = 0.51)
# 3. Years in Current Role and Years with Current Manager (r = 0.71)
#
# **Weakly Correlated Variables :**
#
# 1. Age and Job Level (r = 0.28)
# 2. Education and Total Working Years (r = 0.14)
# 3. Years Since Last Promotion and Years at Company (r = 0.37)
#
# **No Significant Correlation :**
#
# 1. Age and Job Satisfaction (r = 0.03)
# 2. Daily Rate and Total Working Years (r = 0.07)
# 3.Performance Rating has no significant correlations with any variable.

# %% [markdown]
# ### Scatter Plots
#
# **Highly correlated variables**

# %%
# Job Level vs Monthly Income
plt.figure(figsize=(6, 4))
sns.scatterplot(x=df["JobLevel"], y=df["MonthlyIncome"])
plt.title("21BCE2781 - Job Level vs Monthly Income")
plt.xlabel("Job Level")
plt.ylabel("Monthly Income")
plt.show()

# Total Working Years vs Years at Company
plt.figure(figsize=(6, 4))
sns.scatterplot(x=df["TotalWorkingYears"], y=df["YearsAtCompany"])
plt.title("21BCE2781 - Total Working Years vs Years at Company")
plt.xlabel("Total Working Years")
plt.ylabel("Years at Company")
plt.show()

# Years at Company vs Years in Current Role
plt.figure(figsize=(6, 4))
sns.scatterplot(x=df["YearsAtCompany"], y=df["YearsInCurrentRole"])
plt.title("21BCE2781 - Years at Company vs Years in Current Role")
plt.xlabel("Years at Company")
plt.ylabel("Years in Current Role")
plt.show()

# Years at Company vs Years with Current Manager
plt.figure(figsize=(6, 4))
sns.scatterplot(x=df["YearsAtCompany"], y=df["YearsWithCurrManager"])
plt.title("21BCE2781 - Years at Company vs Years with Current Manager")
plt.xlabel("Years at Company")
plt.ylabel("Years with Current Manager")
plt.show()

# %% [markdown]
# **Moderately correlated variables**

# %%
# Age vs Total Working Years
plt.figure(figsize=(6, 4))
sns.scatterplot(x=df["Age"], y=df["TotalWorkingYears"])
plt.title("21BCE2781 - Age vs Total Working Years")
plt.xlabel("Age")
plt.ylabel("Total Working Years")
plt.show()

# Job Level vs Total Working Years
plt.figure(figsize=(6, 4))
sns.scatterplot(x=df["JobLevel"], y=df["TotalWorkingYears"])
plt.title("21BCE2781 - Job Level vs Total Working Years")
plt.xlabel("Job Level")
plt.ylabel("Total Working Years")
plt.show()

# Years in Current Role vs Years with Current Manager
plt.figure(figsize=(6, 4))
sns.scatterplot(x=df["YearsInCurrentRole"], y=df["YearsWithCurrManager"])
plt.title("21BCE2781 - Years in Current Role vs Years with Current Manager")
plt.xlabel("Years in Current Role")
plt.ylabel("Years with Current Manager")
plt.show()

# %% [markdown]
# **Weakly correlated Variables**

# %%
# Age vs Job Level
plt.figure(figsize=(6, 4))
sns.scatterplot(x=df["Age"], y=df["JobLevel"])
plt.title("21BCE2781 - Age vs Job Level")
plt.xlabel("Age")
plt.ylabel("Job Level")
plt.show()

# Education vs Total Working Years
plt.figure(figsize=(6, 4))
sns.scatterplot(x=df["Education"], y=df["TotalWorkingYears"])
plt.title("21BCE2781 - Education vs Total Working Years")
plt.xlabel("Education")
plt.ylabel("Total Working Years")
plt.show()

# Years Since Last Promotion vs Years at Company
plt.figure(figsize=(6, 4))
sns.scatterplot(x=df["YearsSinceLastPromotion"], y=df["YearsAtCompany"])
plt.title("21BCE2781 - Years Since Last Promotion vs Years at Company")
plt.xlabel("Years Since Last Promotion")
plt.ylabel("Years at Company")
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
# Pair Plot with Regression
sns.pairplot(df, vars=['Age', 'MonthlyIncome', 'TotalWorkingYears'], kind="reg")
plt.show()

# %%
#  Pair Plot with Labels, Colors, and Density Plots
sns.set(style="ticks", color_codes=True)
sns.pairplot(df, height=2, vars=['JobLevel', 'YearsAtCompany', 'YearsInCurrentRole'], hue="Attrition")
plt.show()

# %% [markdown]
# ### A time series dataset typically includes a timestamp or date column that records observations at different points in time for the same entity. In this dataset, there are no explicit time-based columns like "Date," "Timestamp," or "Time."

# %% [markdown]
# ## 1D, 2D, and N-D Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1D Visualization - Histogram and Boxplot
plt.figure(figsize=(10, 5))
sns.histplot(df['MonthlyIncome'], kde=True)
plt.title("Distribution of Monthly Income")
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(x='Attrition', y='Age', data=df)
plt.title("Boxplot of Age by Attrition")
plt.show()

numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Now generate heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(numeric_df.corr(), cmap='coolwarm', annot=False)
plt.title("Correlation Heatmap of Numeric Features")
plt.show()

# Select numerical columns for pairplot
numerical_cols = ['Age', 'MonthlyIncome', 'YearsAtCompany', 'DistanceFromHome']
sns.pairplot(df[numerical_cols])
plt.suptitle("Pairplot of Selected Numerical Features", y=1.02)
plt.show()

# N-D Visualization using Pairplot with hue
sns.pairplot(df[numerical_cols + ['Attrition']], hue='Attrition')
plt.suptitle("Pairplot Colored by Attrition", y=1.02)
plt.show()

# %% [markdown]
# ## Dimensionality Reduction using PCA

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

df_encoded = pd.get_dummies(df, drop_first=True)

X = df_encoded.drop('Attrition_Yes', axis=1)
y = df_encoded['Attrition_Yes']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2)
principal_components = pca.fit_transform(X_scaled)

pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])
pca_df['Attrition'] = y.values

plt.figure(figsize=(8, 6))
sns.scatterplot(data=pca_df, x='PC1', y='PC2', hue='Attrition', palette='Set2')
plt.title('PCA Projection (2D)')
plt.show()

# %% [markdown]
# ## Grouping and Aggregation

# %%
# Average MonthlyIncome by Attrition
avg_income_by_attrition = df.groupby('Attrition')['MonthlyIncome'].mean()
print("Average Monthly Income by Attrition:\n", avg_income_by_attrition)

# Sum of YearsAtCompany by Department
total_years_by_dept = df.groupby('Department')['YearsAtCompany'].sum()
print("\nTotal Years at Company by Department:\n", total_years_by_dept)
# Out:
# Average Monthly Income by Attrition:
#  Attrition
# No     4686.173993
# Yes    3622.737288
# Name: MonthlyIncome, dtype: float64
#
# Total Years at Company by Department:
#  Department
# Human Resources            146
# Research & Development    1990
# Sales                     1124
# Name: YearsAtCompany, dtype: int64

# %% [markdown]
# ## Pivot Table and Crosstab

# %%
# Pivot Table: Average MonthlyIncome by JobRole and Attrition
pivot_table = df.pivot_table(values='MonthlyIncome', index='JobRole', columns='Attrition', aggfunc='mean')
print("Pivot Table - Monthly Income by Job Role and Attrition:\n", pivot_table)

# Crosstab: Frequency of Attrition by Department
crosstab = pd.crosstab(df['Department'], df['Attrition'])
print("\nCrosstab - Department vs Attrition:\n", crosstab)
# Out:
# Pivot Table - Monthly Income by Job Role and Attrition:
#  Attrition                           No          Yes
# JobRole
# Healthcare Representative  6509.075472  7594.800000
# Human Resources            4359.520000  2471.166667
# Laboratory Technician      3389.158416  2843.057143
# Manufacturing Director     6305.407407  5320.200000
# Research Scientist         3303.712230  2595.100000
# Sales Executive            6232.158273  6193.608696
# Sales Representative       2754.257143  2259.125000
#
# Crosstab - Department vs Attrition:
#  Attrition                No  Yes
# Department
# Human Resources          25    6
# Research & Development  347   65
# Sales                   174   47

# %% [markdown]
# ##Apply Function (Feature Engineering)

# %%
# Categorize MonthlyIncome
def categorize_income(income):
    if income < 3000:
        return 'Low'
    elif 3000 <= income < 7000:
        return 'Medium'
    else:
        return 'High'

df['IncomeCategory'] = df['MonthlyIncome'].apply(categorize_income)
df['IncomeCategory'].value_counts().plot(kind='bar', title='Income Categories')
plt.show()

# %% [markdown]
# ## 3D Visualization using PCA

# %%
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D

# Already scaled as X_scaled
pca_3d = PCA(n_components=3)
pc_3d = pca_3d.fit_transform(X_scaled)

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(pc_3d[:, 0], pc_3d[:, 1], pc_3d[:, 2], c=y, cmap='coolwarm')
ax.set_title('3D PCA Visualization')
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
plt.show()

# %% [markdown]
# ## K-Means Clustering with Elbow Method

# %%
from sklearn.cluster import KMeans

# Try clustering on 2 numerical features
X_cluster = df[['MonthlyIncome', 'Age']].dropna()

# Elbow Method
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X_cluster)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss, marker='o')
plt.title('Elbow Method for Optimal Clusters')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# Final model
kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict(X_cluster)

# Plot clusters
plt.figure(figsize=(8,6))
sns.scatterplot(x=X_cluster['MonthlyIncome'], y=X_cluster['Age'], hue=df['Cluster'], palette='Set1')
plt.title("K-Means Clusters: Income vs Age")
plt.xlabel("Monthly Income")
plt.ylabel("Age")
plt.show()

# %% [markdown]
# ## Hierarchical Clustering

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# Dendrogram
plt.figure(figsize=(10, 7))
dendrogram = sch.dendrogram(sch.linkage(X_cluster, method='ward'))
plt.title("Dendrogram")
plt.xlabel("Employees")
plt.ylabel("Euclidean Distance")
plt.show()

# Agglomerative Clustering
hc = AgglomerativeClustering(n_clusters=3)
df['HCluster'] = hc.fit_predict(X_cluster)

# %% [markdown]
# ## Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
# Evaluation
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[161   1]
#  [ 34   4]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.83      0.99      0.90       162
#         True       0.80      0.11      0.19        38
#
#     accuracy                           0.82       200
#    macro avg       0.81      0.55      0.54       200
# weighted avg       0.82      0.82      0.77       200
#
# Accuracy Score: 0.825

# %%
# Logistic Regression
log_model = LogisticRegression(max_iter=1000)
log_model.fit(X_train, y_train)
y_log_pred = log_model.predict(X_test)

print("Logistic Regression Accuracy:", accuracy_score(y_test, y_log_pred))
# Out:
# Logistic Regression Accuracy: 0.865

# %% [markdown]
# ## Model Evaluation Summary

# %% [markdown]
# The classification models were evaluated using accuracy, precision, recall, and F1-score metrics. Two models were tested:
#
# 1) Random Forest Classifier:
#
# *   Accuracy: 82.5%
# *   Precision (for 'Yes' class): 0.80
# *   Recall (for 'Yes' class): 0.11
# *   F1-score (for 'Yes' class): 0.19
#
#
# Although the overall accuracy is high, the model struggles with correctly identifying employees who left (Attrition = Yes), as shown by the low recall of 0.11 for the positive class. This indicates a class imbalance or model bias towards predicting Attrition = No.
#
#
# 2) Logistic Regression:
#
# *   Accuracy: 86.5%
#
#
# This model performed slightly better in terms of overall accuracy. However, further analysis of class-wise precision and recall should be conducted to confirm if it handles the minority class better.
